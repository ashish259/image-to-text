# %%
from IPython.display import Image
Image(filename='D:\\Users\\ashis\\marksheet.jpg')

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract  



pytesseract.pytesseract.tesseract_cmd='C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
# pytesseract.pytesseract.tesseract_cmd=subprocess.call(["C:\\Users\\ashis\\Downloads\\tesract.exe"], shell=True)
from pdf2image import convert_from_path
def ocr_core(input_image):
    text=pytesseract.image_to_string(input_image)
    return text

file_name='D:\\Users\\ashis\\marksheet.jpg'
image_type=file_name.split(".")[-1]
if image_type=='pdf':
    pages=convert_from_path('pdf_file',500)
input_data=Image.open(file_name) 
text_dat=ocr_core(input_data)
# txt_file = open('img2txt.txt', 'w+')
# txt_file.write(text_dat.encode('UTF-8'))
# txt_file.close()
print(text_dat)
shape_data=len(text_dat)
# Out:
# 048731
#
# Huse, >
# BOARD OF SECONDARY EDUCATION, MADHYA PRADESH, BHOPAL
# err Savstt eae uieitna] weiter (10+2) 2013
# {) _ HIGHER SECONDARY SCHOOL CERTIFICATE EXAMINATION (10+2) 2013
# LC gJsuppiewentary — icmaelt we-warorat am/sno, 684485
# Cas ut y-2013 MARKSHEET CUM-CERTIFICATE
# & | Menem | ater / tian aoe E “fraareaeac
#
# Eatias |
# |, Sobo.No: | etmoweyfepsteaTon oT otha
# TE zeroes
#
#
#
#
#
#
#
#
#
#
#
# aime sonezoizete
#
#
#
#
#
#
#
# wera fear rar fs 4 |
# CERTIFIED THAT fa wy.
# SHRI/ SUSHR! DHIRAJ GROVER wel
# vate
#
# Re ae ert
# FATHER'S / HUSBAND'S NAME IS BRAJMOHAN GROVER:
#
# aaa t
#
# AND MOTHER'S NAMES” NEENA GROVER
#
# yamvae ate taste “eft ant-2013 teen /oz** arate ge
#
# APPEARED IN THE HIGHER SECONDARY SCHOOL CERTIFICATE EXAMINATION OF THIS BOARD IN THE YEAR 2013
# FROM (SCHOOL / CENTRE)"GovT BOYS H'S SCHOOL, MANASA NEEMUCH
#
# ware
#
# ‘AND HAS BEEN DECLARED PASS IN SECOND DIVISION
# cae Fee B=
#
# ‘SUBJECT WISE MARKS OBTAINED ARE AS UNDER
#
#
#
#
#
#
#
# ...
